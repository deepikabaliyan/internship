# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data. This task will be done in following steps:
#
# first get the webpage https://www.naukri.com/
# Enter “Data Analyst” in “Skill,Designations,Companies” field and enter “Bangalore” in “enter the location” field.
# Then click the search button.
# Then scrape the data for the first 10 jobs results you get.
# Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
#opening the website on automated browser page
url = "https://www.naukri.com/"
driver.get(url)

# %%
#entring desingnation and location as per question
desingnation=driver.find_element(By.CLASS_NAME,"suggestor-input")
desingnation.send_keys('Data Analyst')

# %%
#Entering Data into Search Bars :-
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
#Clicking the search button:-
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#Creating empty lists for scraping data and use the scraped data to make DataFrame:-
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#Scraping the job-titles:-
title=driver.find_elements(By.XPATH,'//a[@Class="title fw500 ellipsis"]')
for i in title[0:10]:
    title=i.text
    job_title.append(title)
time.sleep(3)

# %%
location=driver.find_elements(By.XPATH,"//li[@Class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in location[0:10]:
    location=i.text
    job_location.append(location)
time.sleep(3)

# %%
#scraping the company_name:-
company=driver.find_elements(By.XPATH, '//a[@Class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    company=i.text
    company_name.append(company)
time.sleep(3)

# %%
#scraping the experience_required:-
experience=driver.find_elements(By.XPATH,'//li[@Class="fleft grey-text br2 placeHolderLi experience"]/span[1]')
for i in experience[0:10]:
    experience=i.text
    experience_required.append(experience)
time.sleep(3)

# %%
print(len("job_title"),len("job_location"),len("company_name"),len("experience_required"))
# Out:
# 9 12 12 19

# %%
# creating the dataframe from the scraped data and taking only first 10 jobs:-
JOB=pd.DataFrame({"experience_required":experience_required,"company_name":company_name,"job_location":job_location,
                "job_title":job_title})
JOB
# Out:
#   experience_required                                    company_name  \
# 0             0-2 Yrs                                       Clarivate
# 1             2-5 Yrs                                   Shell Pvt Ltd
# 2             3-5 Yrs                                   Shell Pvt Ltd
# 3             2-5 Yrs                                   Shell Pvt Ltd
# 4             5-8 Yrs  MM STAFFING CAREER CONSULTANTS PRIVATE LIMITED
# 5             2-4 Yrs                                        Flipkart
# 6            1-12 Yrs                                     Wells Fargo
# 7             5-7 Yrs  MM STAFFING CAREER CONSULTANTS PRIVATE LIMITED
# 8             2-5 Yrs                       S.A.W IT Services Pvt Ltd
# 9             0-4 Yrs                                             WSP
#
#           job_location                                       job_title
# 0  Bangalore/Bengaluru  Associate Healthcare Research and Data Analyst
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, full job-description. You have to scrape first 10 jobs data. This task will be done in following steps:
#
# first get the webpage https://www.naukri.com/
# Enter “Data Scientist” in “Skill,Designations,Companies” field and enter
# “Bangalore” in “enter the location” field. 3. Then click the search button. 4. Then scrape the data for the first 10 jobs results you get. 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
#opening the website on automated browser page
url = "https://www.naukri.com/"
driver.get(url)

# %%
#entring desingnation and location as per question
desingnation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
desingnation.send_keys('Data scientist')

# %%
#Entering Data into Search Bars :-
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
#Clicking the search button:-
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#Creating empty lists for scraping data and use the scraped data to make DataFrame:-
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title=driver.find_elements(By.XPATH,"//a[@Class='title fw500 ellipsis']")
for i in title[0:10]:
    title=i.text
    job_title.append(title)
time.sleep(3)

# %%
location=driver.find_elements(By.XPATH,"//li[@Class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in location[0:10]:
    location=i.text
    job_location.append(location)
time.sleep(3)

# %%
company=driver.find_elements(By.XPATH,"//a[@Class='subTitle ellipsis fleft']")
for i in company[0:10]:
    company=i.text
    company_name.append(company)
time.sleep(3)

# %%
experience=driver.find_elements(By.XPATH,"//li[@Class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience[0:10]:
    experience=i.text
    experience_required.append(experience)
time.sleep(3)

# %%
print(len("job_title"),len("job_location"),len("company_name"),len("experience_required"))
# Out:
# 9 12 12 19

# %%
Jobs=pd.DataFrame({"job_title":job_title[0:10],"job_location":job_location[0:10],"company_name":company_name[0:10],"experience_required":experience_required[0:10]})

Jobs
# Out:
#                                            job_title  \
# 0                   Analystics & Modeling Specialist
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                               Manager-Data Science
# 4                                     Data Scientist
# 5                                Data Scientist - II
# 6                              Senior Data Scientist
# 7   ACN - Applied Intelligence - Data Scientist - 09
# 8  Python Programming Language Data Science Pract...
# 9  ACN - Applied Intelligence - C4DI - Sustainabi...
#
#                                         job_location      company_name  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...         Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...       Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune     Tech Mahindra
# 3                                Bangalore/Bengaluru  AMERICAN EXPRESS
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below: You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company_name, experience_required. The location filter to be used is “Delhi/NCR” The salary filter to be used is “3-6” lakhs The task will be done as shown in the below steps:
#
# first get the webpage https://www.naukri.com/
# Enter “Data Scientist” in “Skill,Designations,Companies” field .
# Then click the search button.
# Then apply the location filter and salary filter by checking the respective boxes
# Then scrape the data for the first 10 jobs results you get.
# Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
Url="https://www.naukri.com/"
driver.get(url)
time.sleep(3)

# %%
desingnation=driver.find_element(By.CLASS_NAME,"suggestor-input")
desingnation.send_keys('Data scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
search=location.send_keys("Delhi/NCR")

# %%
search_button=driver.find_element(By.CLASS_NAME, "qsbSubmit")
search_button.click()
time.sleep(3)

# %%
# finding the salary check box:-
slry_box = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[2]/div[2]/article[1]/div[1]/div[1]/ul/li[2]/span")
slry_box.click()
time.sleep(3)

# %%
# creating empty lists for scraping data and use the scraped data to make DataFrame:-
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title=driver.find_elements(By.XPATH, "//a[@Class='title fw500 ellipsis']")
for i in title[0:10]:
    title=i.text
    job_title.append(title)
time.sleep(3)

# %%
location=driver.find_elements(By.XPATH,"//li[@Class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in location[0:10]:
    location=i.text
    job_location.append(location)
time.sleep(3)

# %%
company=driver.find_elements(By.XPATH,"//a[@Class='subTitle ellipsis fleft']")
for i in company[0:10]:
    company=i.text
    company_name.append(company)
time.sleep(3)

# %%
experience=driver.find_elements(By.XPATH,"//li[@Class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience[0:10]:
    experience=i.text
    experience_required.append(experience)
time.sleep(3)

# %%
Jobs=pd.DataFrame({"job_title":job_title[0:10],"job_location":job_location[0:10],"company_name":company_name[0:10],"experience_required":experience_required[0:10]})

Jobs
# Out:
#                                            job_title  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2                 Data Science - Engineering Manager
# 3  Artificial Intelligence/Computer Vision Engine...
# 4                               Analyst-Data Science
# 5  Hiring For DATA Scientist @ NTT DATA Business ...
# 6           Senior Data Scientist - Machine Learning
# 7                                     Data Scientist
# 8                  Data Scientist - R / Python / SQL
# 9  ACN - Applied Intelligence - Data & Insights -...
#
#                                         job_location  \
# 0  Delhi / NCR, New Delhi, Hyderabad/Secunderabad...
# 1  Hybrid - Noida, Kolkata, Hyderabad/Secunderaba...
# 2                     New Delhi, Bangalore/Bengaluru
# 3  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 4                                   Gurgaon/Gurugram
# 5  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#
# Brand
# Product Description
# Price
# The attributes which you have to scrape is ticked marked in the below image. To scrape the data you have to go through following steps:
#
# Go to Flipkart webpage by url : https://www.flipkart.com/
# Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual.

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
Url="https://www.flipkart.com/"
driver.get(Url)
time.sleep(3)

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search=location.send_keys("sunglasses")

# %%
# clicking the search button:-
search=driver.find_element(By.CLASS_NAME,"_3704LK")

# %%
search_button=driver.find_element(By.CLASS_NAME, "L0Z3Pu")

# %%
# creating empty lists for scraping data and use the scraped data to make DataFrame:-
brand=[]
product_description=[]
price=[]
discount=[]

# %%
brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand[0:100]:
    brand_name=i.text
    brand.append(brand)
time.sleep(3)

# %%
product_desc=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in discount[0:100]:
    description=i.text
    product_desc.append(description)
time.sleep(3)

# %%
product_price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in discount[0:100]:
    price=i.text
    product_price.append(price)
time.sleep(3)

# %%
discount=driver.find_elements(By.XPATH,'//div[@class="__3Ay6Sb"]')
for i in discount[0:100]:
    discount=i.text
    discount.append(discount)
time.sleep(3)

# %%
next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/span[2]')

# %%
brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand[0:100]:
    brand_name=(i.text)
    brand.append(brand)

# %%
product_desc=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in discount[0:100]:
    description=()
    product_desc.append(description)

# %%
product_price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in discount[0:100]:
    price=()
    product_price.append(price)

# %%
discount=driver.find_elements(By.XPATH,'//div[@class="__3Ay6Sb"]')
for i in discount[0:100]:
    discount=()
    discount.append(discount)

# %%
df=pd.DataFrame({'brand':brand,'product_desc':product_desc,'product_price':product_price,'discount':discount})
df
# Out:
# Empty DataFrame
# Columns: [brand, product_desc, product_price, discount]
# Index: []

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. This task will be done in following steps:
#
# First get the webpage https://www.flipkart.com/
# Enter “iphone 11” in “Search” field .
# Then click the search button.
# You will reach to the below shown webpage As shown in the above page you have to scrape the tick marked attributes.These are:
#
# Rating
# Review summary
# Full review
# You have to scrape this data for first 100 reviews.

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
#opening the website on automated browser page
driver.get("https://www.flipkart.com")

# %%
search_input=driver.find_element(By.CLASS_NAME,"_3704LK")
search_input.send_keys('iphone 11')

# %%
#search for the required
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
product=driver.find_element(By.CLASS_NAME,"_4rR01T")
product.click()

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-128-gb/product-reviews/itm8244e8d955aba?pid=MOBFWQ6BKRYBP5X8&lid=LSTMOBFWQ6BKRYBP5X8IBG6BS&marketplace=FLIPKART")

# %%
rating_tags=[]
summary_tags=[]
review_tags=[]

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=(i.text)
    rating_tags.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary_tags[0:100]:
    summary=i.text
    summary_tags.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
print(len(rating_tags),len(summary_tags),len(review_tags))
# Out:
# 20 20 20

# %%
df=pd.DataFrame({'rating_tags':rating_tags,'summary_tags':summary_tags,'review_tags':review_tags})
df
# Out:
#                                           rating_tags  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10                                                  5
# 11                                                  5
# 12                                                  5
# 13                                                  5
# 14                                                  5
# 15                                                  5
# ...

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field. You have to scrape 4 attributes of each sneaker:
#
# Brand
# Product Description
# Price
# As shown in the below image, you have to scrape the tick marked attributes.

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
#opening the website on automated browser page
driver.get("https://www.flipkart.com")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')  
search.click()

# %%
search_input=driver.find_element(By.CLASS_NAME,"_3704LK")
search_input.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
time.sleep(3)

# %%
brand_tags=[]
description_tags=[]
price_tags=[]
discount_tags=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=(i.text)
    brand_tags.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    description=i.text
    description_tags.append(description)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:100]:
    price=i.text
    price_tags.append(price)
    
discount_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount_tags[0:100]:
    discount=i.text
    discount_tags.append(discount)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[3]')
next_button.click()

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=(i.text)
    brand_tags.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    description=i.text
    description_tags.append(description)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:100]:
    price=i.text
    price_tags.append(price)
    
discount_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount_tags[0:100]:
    discount=i.text
    discount_tags.append(discount)

# %%
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span')
next_button.click()

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=(i.text)
    brand_tags.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    description=i.text
    description_tags.append(description)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:100]:
    price=i.text
    price_tags.append(price)
    
discount_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount_tags[0:100]:
    discount=i.text
    discount_tags.append(discount)

# %%
print(len(brand_tags),len(description_tags),len(description_tags))
# Out:
# 80 72 72

# %%
df=pd.DataFrame({'brand_tags':brand,'description_tags':description,'price_tags':price,'discount_tags':discount,})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [209], in <cell line: 1>()
# ----> 1 df=pd.DataFrame({'brand_tags':brand,'description_tags':description,'price_tags':price,'discount_tags':discount,})
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)

# %%
driver.get("https://www.amazon.in/")

# %%
search_input=driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')
search_input.send_keys('Laptop')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
cpu_filter_i7 = driver.find_element(By.XPATH,'//li[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
cpu_filter_i7.click()

# %%
title_tags=[]
rating_tags=[]
price_tags=[]

# %%
# Scrapping product title from the webpage
title=[]
for i in driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]')[0:10]:
    title.append(i.text)
    
# Scrapping product price from the webpage
price=[]
for j in driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')[0:10]:
    price.append(j.text)

# converting scrapped data for first 10 Laptops data into DataFrame
Laptop=pd.DataFrame({'Title':title,'Price':price}) 
Laptop.head(10)
# Out:
#                                                Title     Price
# 0  Sponsored\nHP Pavilion x360 11th Gen Intel Cor...    82,490
# 1  Sponsored\nAcer Swift 5 Intel Evo Premium 14 I...  1,05,385
# 2  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...    95,546
# 3  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...    82,990
# 4  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...    89,000
# 5  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    82,490
# 6  Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD ...    79,990
# 7  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...    24,939
# 8  ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...  1,49,900
# 9  Lenovo Yoga 7 Intel Evo i7 1260P 14"(35.56cm) ...  1,11,990

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps: 1.First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quote

# %%
#getting webdriver
driver = webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#getting webpage https://www.ambitionbox.com/
driver.get('https://www.azquotes.com')

# %%
TP=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
TP.click()

# %%
Quote = []
Author = []
Type_of_quote = []

# %%
# scraping filtered Quote from the given page

quo=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quo[0:100]:
    ti=i.text
    Quote.append(ti)

# %%
# scraping Author from the given page

Aut=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in Aut[0:100]:
    rat=i.text
    Author.append(rat)

# %%
# scraping Description from given page

desc=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in desc[0:100]:
    de=i.text
    Type_of_quote.append(de)

# %%
FIL_DATA = pd.DataFrame({
    'Quote':Quote[0:100],
    'Author':Author[0:100],
    'Type_of_quote':Type_of_quote[0:100]})

FIL_DATA
# Out:
#                                                 Quote                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                Type_of_quote
# ...

# %% [markdown]
# Q10: Write s python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# First get the webpage https://www.jagranjosh.com/
# Then You have to click on the GK option
# Then click on the List of all Prime Ministers of India
# Then scrap the mentioned data and make the DataFrame

# %%
driver.get('https://www.jagranjosh.com/')

# %%
GK=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a")
GK.click()

# %%
List_PM=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
List_PM.click()

# %%
Name=[]
Born_dead=[]
Term=[]
Remark=[]

# %%
#Xpath of all data name,born,term,remarks
name=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
born_Dead=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
term_of_office=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p[1]')
remarks=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')

# %%
#Create List of all data
Name=[i.text for i in name]
Born_Dead=[i.text for i in born_Dead]
Term_of_office=[i.text for i in term_of_office]
Remarks=[i.text for i in remarks]

# %%
df=pd.DataFrame({
    'Name':Name,
    'Born_Dead':Born_Dead,
    'Term_of_office':Term_of_office,
    'Remarks':Remarks
})
df
# Out:
#                            Name     Born_Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                          Term_of_office  \
# ...

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name ,Description and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on leftside.
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make th

# %%
#getting webdriver
driver = webdriver.Chrome(r"C:\Users\Admin\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# search on google is https://www.motor1.com/
driver.get("https://www.motor1.com/")
time.sleep(3)

# %%
#Click to open dropbox
Click_d=driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/div/div[1]/div")
Click_d.click()
time.sleep(1)

# %%
#click on features
Click_f=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[5]/button")
Click_f.click()
time.sleep(1)

# %%
#click on list
Click_l=driver.find_element(By.XPATH,'//a[text()="Lists"]')
Click_l.click()
time.sleep(1)

# %%
#click on 50 Most Expensive Cars In The World
Click_50=driver.find_element(By.XPATH,'//a[text()="50 Most Expensive Cars In The World"]')
Click_50.click()
time.sleep(2)

# %%
#Car Name
name=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
name=[i.text for i in name[0:50]]
# print(len(name))

# %%
#Car price
price=driver.find_elements(By.XPATH,'//div[@class="postBody description e-content"]/p/strong')
price=[i.text for i in price[0:50]]
# print(len(price))

# %%
#Car Descriptipons
description=driver.find_elements(By.XPATH,'//div[@class="postContent content-wrapper"]/div/p')
Description=[i.text for i in description]
x=Description[4:]

# %%
des=[]
for i in range(0,99,2):
    if i%2==0:
        des.append(x[i])

# %%
df=pd.DataFrame({
    "Car_Name":name,
    "Description":des,
    "Price":price
})
df
# Out:
#                            Car_Name  \
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# ...
